# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_crime = pd.read_csv("csvs\Base.csv")
df_crime
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0                0     0.9               0.990415                         11
# 1                0     0.4               0.781728                         -1
# 2                0     0.7               0.274290                         -1
# 3                0     0.9               0.722684                         -1
# 4                0     0.9               0.121661                         -1
# ...            ...     ...                    ...                        ...
# 999995           0     0.9               0.173671                         -1
# 999996           0     0.9               0.566285                         -1
# 999997           0     0.6               0.807476                         -1
# 999998           0     0.8               0.151376                         87
# 999999           0     0.8               0.145820                         63
#
# ...

# %%
df_crime.dtypes
# Out:
# fraud_bool                            int64
# income                              float64
# name_email_similarity               float64
# prev_address_months_count             int64
# current_address_months_count          int64
# customer_age                          int64
# days_since_request                  float64
# intended_balcon_amount              float64
# payment_type                         object
# zip_count_4w                          int64
# velocity_6h                         float64
# velocity_24h                        float64
# velocity_4w                         float64
# bank_branch_count_8w                  int64
# date_of_birth_distinct_emails_4w      int64
# employment_status                    object
# credit_risk_score                     int64
# email_is_free                         int64
# housing_status                       object
# phone_home_valid                      int64
# phone_mobile_valid                    int64
# ...

# %%
df_crime[:].isnull
# Out:
# <bound method DataFrame.isnull of         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0                0     0.9               0.990415                         11
# 1                0     0.4               0.781728                         -1
# 2                0     0.7               0.274290                         -1
# 3                0     0.9               0.722684                         -1
# 4                0     0.9               0.121661                         -1
# ...            ...     ...                    ...                        ...
# 999995           0     0.9               0.173671                         -1
# 999996           0     0.9               0.566285                         -1
# 999997           0     0.6               0.807476                         -1
# 999998           0     0.8               0.151376                         87
# 999999           0     0.8               0.145820                         63
#
# ...
